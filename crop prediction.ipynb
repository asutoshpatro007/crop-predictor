# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\asuto\\Desktop\\3rd sem\\python\\anaconda\\crop prediction\\cpdata.csv")

# %%
df.head()
# Out:
#    temperature   humidity        ph    rainfall label
# 0    20.879744  82.002744  6.502985  202.935536  rice
# 1    21.770462  80.319644  7.038096  226.655537  rice
# 2    23.004459  82.320763  7.840207  263.964248  rice
# 3    26.491096  80.158363  6.980401  242.864034  rice
# 4    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.groupby('label').mean()['temperature'].plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
df.groupby('label').mean()
# Out:
#               temperature   humidity        ph    rainfall
# label
# Adzuki Beans    52.685384  52.423402  6.206098  106.820950
# Black gram      29.973340  65.118426  7.133952   67.884151
# Chickpea        18.872847  16.860439  7.336957   80.058977
# Coconut         27.409892  94.844272  5.976562  175.686646
# Coffee          25.540477  58.869846  6.790308  158.066295
# Cotton          23.988958  79.843474  6.912675   80.398043
# Ground Nut      32.081756  64.714734  6.228549  104.728854
# Jute            24.958376  79.639864  6.732778  174.792798
# Kidney Beans    20.115085  21.605357  5.749411  105.919778
# Lentil          24.509052  64.804785  6.927932   45.680454
# Moth Beans      28.194920  53.160418  6.831174   51.198487
# Mung Bean       28.525775  85.499975  6.723957   48.403601
# Peas            17.560221  13.529381  6.429157   50.394917
# Pigeon Peas     27.741762  48.061633  5.794175  149.457564
# Rubber          27.056811  70.462598  5.295847  292.717489
# ...

# %%
sns.distplot(x=df['temperature'])
# Out:
# C:\Users\asuto\AppData\Local\Temp\ipykernel_1632\1146910799.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['temperature'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['humidity'])
# Out:
# C:\Users\asuto\AppData\Local\Temp\ipykernel_1632\3309897050.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['humidity'])
# <Axes: xlabel='humidity', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
X = df[['temperature', 'humidity', 'ph', 'rainfall']]
y = df['label']

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=23)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_pred)

# %%
print('the accuracy of the model is: ',acc*100)
# Out:
# the accuracy of the model is:  90.64516129032259

# %%
import joblib

# %%
joblib.dump(model,'crop.pkl')
# Out:
# ['crop.pkl']
